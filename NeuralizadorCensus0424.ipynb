# %% [markdown]
# <a href="https://colab.research.google.com/github/victoricoma/am-t4-s1a2026/blob/main/NeuralizadorCensus0424.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipe de Neuralização do Census Data

# %% [markdown]
# ## Importar dados do Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Bibliotecas de Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
