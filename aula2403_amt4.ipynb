# %% [markdown]
# <a href="https://colab.research.google.com/github/victoricoma/am-t4-s1a2026/blob/main/aula2403_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=2
b=3
print('A some é: ',a+b)
# Out:
# A some é:  5

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print('A multiplicação é: ',c*d)
# Out:
# A multiplicação é:  20

# %% [markdown]
# # Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Numero sem raiz', delta

  x1 = (-b + math.sqrt(delta)) /(2*a)
  x2 = (-b - math.sqrt(delta)) /(2*a)

  return x1, x2

# %% [markdown]
# ## Testes de Função Matemática

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  eq += equacao2grau(a, b, c)

# %%
print(eq)
# Out:
# (2.0, 1.0, 'Numero sem raiz', -119, -0.859945055359741, -8.140054944640259, -1.7807764064044151, 0.28077640640441515, -5.741657386773941, 1.7416573867739413, 'Numero sem raiz', -128)
